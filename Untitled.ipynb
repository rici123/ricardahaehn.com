# %%
import mahotas as mh

# %%
import os

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /home/d/miniconda3/lib/python3.8/site-packages/IPython/core/magics/pylab.py:159: UserWarning: pylab import has clobbered these variables: ['f']
# `%matplotlib` prevents importing * from pylab and numpy
#   warn("pylab import has clobbered these variables: %s"  % clobbered +

# %%
fs = sorted(os.listdir('.'))

# %%
img1 = np.zeros((1))

# %%
img1.shape[0]
# Out:
# 1

# %%
img1 = np.zeros((1))
img2 = None
olddiff = 0
realframes = [fs[0]]
for f in fs:
    if f.startswith('frame'):
        if img1.shape[0] == 1:
            img1 = mh.imread(f)
            continue
        img2 = mh.imread(f)
        diff = np.mean(img2 - img1)
        if abs(olddiff - diff) > 2:
            realframes.append(f)
        olddiff = diff
        print(f, np.mean(diff))
# Out:
# frame0008.png 155.81444950810186
# frame0009.png 155.58052191840278
# frame0010.png 154.45336443865742
# frame0015.png 141.489248046875
# frame0017.png 145.94630823206018
# frame0018.png 145.9317672164352
# frame0019.png 145.9359403935185
# frame0020.png 145.94102936921297
# frame0021.png 145.94645905671297
# frame0022.png 155.70223849826388
# frame0023.png 155.70314019097222
# frame0024.png 154.11079427083334
# frame0025.png 154.13506763599537
# frame0026.png 154.15396556712963
# frame0027.png 154.16624457465278
# frame0028.png 154.1543916377315
# frame0029.png 145.32708767361112
# frame0030.png 145.33967230902778
# frame0031.png 142.91863932291668
# frame0032.png 142.91383608217592
# frame0033.png 142.91596860532408
# frame0034.png 142.9167552806713
# frame0035.png 142.91769965277777
# frame0036.png 133.0998629195602
# frame0037.png 133.09446433738427
# frame0038.png 133.06805953414352
# frame0039.png 133.0689572482639
# frame0040.png 133.07494755497686
# ...

# %%
len(realframes)
# Out:
# 83

# %%
realframes
# Out:
# ['.git',
#  'frame0008.png',
#  'frame0015.png',
#  'frame0017.png',
#  'frame0022.png',
#  'frame0029.png',
#  'frame0031.png',
#  'frame0036.png',
#  'frame0043.png',
#  'frame0045.png',
#  'frame0052.png',
#  'frame0057.png',
#  'frame0064.png',
#  'frame0066.png',
#  'frame0071.png',
#  'frame0078.png',
#  'frame0085.png',
#  'frame0087.png',
#  'frame0092.png',
#  'frame0099.png',
#  'frame0106.png',
#  'frame0113.png',
#  'frame0115.png',
#  'frame0120.png',
#  'frame0127.png',
#  'frame0134.png',
#  'frame0136.png',
#  'frame0141.png',
#  'frame0143.png',
#  'frame0148.png',
#  'frame0155.png',
#  'frame0157.png',
#  'frame0162.png',
#  'frame0169.png',
#  'frame0171.png',
#  'frame0176.png',
#  'frame0183.png',
#  'frame0185.png',
#  'frame0190.png',
#  'frame0197.png',
#  'frame0204.png',
#  'frame0211.png',
#  'frame0213.png',
#  'frame0218.png',
#  'frame0225.png',
#  'frame0227.png',
#  'frame0232.png',
#  'frame0239.png',
#  'frame0241.png',
#  'frame0246.png',
# ...

# %%
import shutil
for f in realframes[1:]:
    shutil.copy(f, 'pngs/'+f)
